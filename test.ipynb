# %%
import requests
from bs4 import BeautifulSoup
import time

# %%
# Out:
# hellp

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:125.0) Gecko/20100101 Firefox/125.0",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8",
    "Accept-Language": "en-US,en;q=0.5",
    "Alt-Used": "www.ewg.org",
    "Upgrade-Insecure-Requests": "1",
    "Sec-Fetch-Dest": "document",
    "Sec-Fetch-Mode": "navigate",
    "Sec-Fetch-Site": "none",
    "Sec-Fetch-User": "?1"
}

# %%
with open('1.txt', 'r') as file:
    all_1 = file.readlines()

# %%
all_1

# %%
URL = "https://www.ewg.org/foodscores/products/?search=agnolotti"

page = requests.get(URL, headers=headers)

soup = BeautifulSoup(page.content, "html.parser")

target = soup.find(id="showing")

# %%
print(target)
# Out:
# <div class="fleft" id="showing">
# <div class="wrap_title_ty">
# Showing
# <span id="span_pagination">1
# to 2
# of 2
# </span>
# Search results for <span id="results_for_name">"agnolotti"</span>
# </div>
# </div>

# %%
soup
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html lang="en-US" prefix="og: http://ogp.me/ns#" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://ogp.me/ns/fb#">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="always" name="referrer"/>
# <title>EWG's Food Scores | Search results: agnolotti</title>
# <meta content="EWG's Food Scores just took the work out of grocery shopping for me!" name="title">
# <meta content="EWG's Food Scores just took the work out of grocery shopping for me!" property="og:title">
# <meta content="How do we know what we are eating, really? Find out with @EWG Food Scores! #FoodAnswered  @EWG Food Scores! #FoodAnswered" name="twitter:title"/>
# <meta content="noindex" name="robots"/>
# <meta content="EWG's Food Scores rates more than 80,000 foods in a simple, searchable online format to empower people to shop smarter and eat healthier. Each item in the database is scored based on three factors: nutrition, ingredient concerns and degree of processing. &lt;a href='http://ewg.org/foodscores/'&gt;Check it out and see how your favorite foods score.&lt;/a&gt;" name="description">
# <meta content="EWG's Food Scores rates more than 80,000 foods in a simple, searchable online format to empower people to shop smarter and eat healthier. Each item in the database is scored based on three factors: nutrition, ingredient concerns and degree of processing. &lt;a href='http://ewg.org/foodscores/'&gt;Check it out and see how your favorite foods score.&lt;/a&gt;" property="og:description">
# <meta content="EWG's Food Scores rates more than 80,000 foods in a simple, searchable online format to empower people to shop smarter and eat healthier. Each item in the database is scored based on three factors: nutrition, ingredient concerns and degree of processing. &lt;a href='http://ewg.org/foodscores/'&gt;Check it out and see how your favorite foods score.&lt;/a&gt;" name="twitter:description"/>
# <meta content="EWG - Environmental Working Group" name="author">
# <meta content="EWG - Environmental Working Group © 2024 " name="Copyright"/>
# <meta content="EWG, Environment, Health, Food, Nutrition, Healthy, Produce, Products, Shop, Shopping, Good Food,Food Answered, Food Scores, Grocery Store, Rate your plate, Supermarket" name="keywords"/>
# <script src="/cdn-cgi/apps/head/bLMY4IbeO5Zdzi60Vrh0H1RYRxE.js"></script><link href="https://www.ewg.org/foodscores/assets/food_database_stylesheet/share_image-37e9c8d3f0ff2600e6fcf1615c631fa6552d92fbf05c89c17906a41596d860db.jpg" rel="image_src"/>
# <meta content="http://www.ewg.org/foodscores/assets/food_database_stylesheet/share_image-37e9c8d3f0ff2600e6fcf1615c631fa6552d92fbf05c89c17906a41596d860db.jpg" property="og:image"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@EWG" name="twitter:site"/>
# <meta content="@EWG" name="twitter:creator"/>
# <meta content="http://www.ewg.org/foodscores/assets/food_database_stylesheet/share_image-37e9c8d3f0ff2600e6fcf1615c631fa6552d92fbf05c89c17906a41596d860db.jpg" name="twitter:image:src"/>
# <link href="https://cdn.ewg.org/sites/all/themes/EWG/apple-touch-icon-144x144-favicon.png" rel="shortcut icon"/>
# <link href="https://cdn.ewg.org/sites/all/themes/EWG/apple-touch-icon-144x144-favicon.png" rel="apple-touch-icon" sizes="144x144"/>
# <meta content="yes" name="apple-mobile-web-app-capable">
# <meta content="black" name="apple-mobile-web-app-status-bar-style">
# <script>(function(w,d,s,n,a){if(!w[n]){var l='call,catch,on,once,set,then,track'
# .split(','),i,o=function(n){return'function'==typeof n?o.l.push([arguments])&&o
# :function(){return o.l.push([n,arguments])&&o}},t=d.getElementsByTagName(s)[0],
# j=d.createElement(s);j.async=!0;j.src='https://cdn.fundraiseup.com/widget/'+a;
# t.parentNode.insertBefore(j,t);o.s=Date.now();o.v=4;o.h=w.location.href;o.l=[];
# for(i=0;i<7;i++)o[l[i]]=o(l[i]);w[n]=o}
# })(window,document,'script','FundraiseUp','AKWZXHJB');</script>
# <link href="/foodscores/assets/food_database-c01be38420c972869df816425b6defbf2d726baab17096ea305ad258fd3b8295.css" media="all" rel="stylesheet"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.7.2/jquery.min.js" type="text/javascript"></script>
# <script src="/foodscores/assets/food_database-f3d7b9390b17fdd029aad408ad74d197f3f62eb38e0e950e7e49b2cdb02e7567.js"></script>
# <meta content="authenticity_token" name="csrf-param">
# <meta content="sC-PAs2uTEKB6kx8UdHnkvNFJFW9SWaSbuMvoXmraPKhtocHOiA0Whu2SljER8MbxIRYIT-M2FM3qvL238C4tA" name="csrf-token">
# <link href="https://fonts.googleapis.com/css?family=Open+Sans:300,300italic,400,400italic,600,600italic,700,700italic,800,800italic" rel="stylesheet" type="text/css"/>
# </meta></meta></meta></meta></meta></meta></meta></meta></meta></head>
# <body>
# <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-PPNMZJ" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-PPNMZJ');</script>
# <div class="noshow" id="admin_menu">
# <img id="admin_menu_icon" src="/foodscores/assets/phorcys_icon-c4ba6c221c7c6e4b3bc181abec7c2b0ab2d664c1a61a3ef1430207e6fb2f4fb6.png"/>
# <ul>
# <li class="expandable-red"><a href="/foodscores/?show_admin_menu=no">Remove Admin Menu</a></li>
# </ul>
# </div>
# <div id="loading"></div>
# <div class="noshow" id="mywidthdiv"></div>
# <div id="top_line"> </div>
# <div id="top"> </div>
# <div id="gototop_arrow"><a class="scroll nounderlineahref" href="#top"><img class="noborder nounderlineahref" src="/foodscores/assets/food_database_stylesheet/up_arrow-095fb817ea7273c547e82f5a28c1ea5e11997d4ef2aefbe796d422da343aa949.png"/></a></div>
# <div class="mfp-hide white-popup-block6 zoom-anim-dialog" id="download_app_popup">
# <h1 class="noshow">On the go? Download our Mobile App</h1>
# <div class="clear"></div>
# </div>
# <div class="overthrow NO_nano" id="menu_ty">
# <div class="MOVE_UP_overthrow NO_content">
# <h3 class="noshow">Navigate EWG's Food Scores:</h3>
# <h1>Menu:</h1>
# <div id="menu_ty_inner">
# <ul>
# <li><a href="/foodscores" title="Home">Home</a></li>
# <li><a href="/foodscores/content/user-guide" title="User's Guide">User's Guide</a></li>
# <li><a href="/foodscores/content/faq" title="FAQ">FAQ</a></li>
# <li><a class="popup-with-form" href="#contact_front" title="contact Us">Contact Us</a></li>
# <li><a href="https://act.ewg.org/onlineactions/0fgkOtqcjUyKPgiREUE1AA2?sourceid=1009137" title="Help Supprt EWG">Support EWG</a></li>
# <li><a class="popup-with-form" href="#popup4" id="make_green_white">Email Sign Up!</a></li>
# <li></li>
# <div class="clear"></div>
# </ul>
# <div class="disclaimers_below_search_results_mobile" id="legal_search_prod_images_mobile">Please note that EWG obtains the displayed images of products from third parties and that the product's manufacturer or packager may change the product's packaging at any point in time. Therefore, EWG assumes no responsibility for the accuracy of images presented.</div>
# <p id="mobile_title_about">About EWG's Food Scores</p>
# <div id="mobile_about_ratings_txt"> </div>
# </div>
# </div>
# </div>
# <div id="sticky_menu">
# <div id="header">
# <div id="top_header">
# <div class="fleft" id="logo_div">
# <a class="nounderlineahref" href="https://www.ewg.org/">
# <img alt="EWG" class="noborder logo2015_2_pc" height="90" src="/foodscores/assets/food_database_stylesheet/ewg_logo_2015_2-dcc390677fde4cfab39757dbcecc93eb9ffd10a1b1b69807c52ec1e84a11b6a0.png" width="282"/>
# </a>
# </div>
# <div class="fright" id="tools_div">
# <div class="fright" id="admin">
# <a class="nounderlineahref" href="https://act.ewg.org/onlineactions/0fgkOtqcjUyKPgiREUE1AA2?sourceid=1009137" title="Donate to EWG"><div class="orange admin_col fleft" id="admin_left">Donate</div></a>
# <a class="nounderlineahref scroll_new" href="#ewg_guides"><div class="admin_col fleft" id="guides_icon"><div id="guide_icon_img"><img alt="EWG Guides" height="12" src="/foodscores/assets/food_database_stylesheet/guides_icon-38128c80311970bcb189e161d32b38218af16766d0c3df8328dacae7f17e4fd9.png" title="EWG Guides" width="10"/></div>ewg guides</div></a>
# <a class="nounderlineahref" href="/foodscores/content/faq" title="FAQ"><div class="admin_col fleft" id="faq_icon"><div id="faq_icon_img"><img alt="FAQ" height="12" src="/foodscores/assets/food_database_stylesheet/faq-efffe8639a08611e54ea1196822368b34b2efb4b4d2de777a6f522412863e676.png" title="FAQ" width="12"/></div>faq</div></a>
# <a class="nounderlineahref" href="/foodscores/content/user-guide" title="User’s Guide"><div class="admin_col fleft" id="admin_right"><div class="noshow" id="info_icon_img"><img alt="user’s guide" height="18" src="/foodscores/assets/food_database_stylesheet/info-8af2d209f1a809fc113d187d0f1f7bc174d1e07aec7b33776ad478a776a593f0.png" title="user’s guide" width="5"/></div>user’s guide</div></a>
# <div class="clear"></div>
# </div>
# <div class="fright" id="searches_since">
# <span id="searches_count"></span> searches since Oct. 27, 2014
# </div>
# <div class="clear"></div>
# <ul class="clearfix fright" id="socialmedia_ul">
# <li class="fleft"><a class="sm_facebook" href="https://www.facebook.com/ewg.org" title="Facebook">Facebook</a></li>
# <li class="fleft"><a class="sm_twitter" href="https://twitter.com/ewg" title="Twitter">Twitter</a></li>
# <li class="fleft"><a class="sm_pinterest" href="https://www.pinterest.com/ewgnonprofit/" title="Pinterest">Pinterest</a></li>
# <li class="fleft"><a class="sm_youtube" href="https://www.youtube.com/user/EnvironmentalWG" title="YouTube">YouTube</a></li>
# <div class="clear"></div>
# </ul>
# <div class="clear"></div>
# </div>
# <div class="clear"></div>
# </div>
# <div id="bottom_header">
# <div class="fleft" id="dropdown">
# <a class="noborder nounderlineahref" href="https://www.ewg.org/foodscores" rel="home" title="EWG's Food Scores"><div class="fleft" id="home">EWG's Food Scores</div></a>
# <a class="noborder nounderlineahref fleft" href="https://www.ewg.org/foodscores" id="ewg_fd_href" rel="home" title="EWG's Food Scores">
# <div class="fright" id="">
# <span id="ewg">EWG's</span> Food Scores
# </div>
# </a>
# <a class="noborder nounderlineahref" href="#" title="Show aisles">
# <div class="fright" id="down">Categories</div>
# </a>
# <div class="clear"></div>
# </div>
# <div class="fright" id="search">
# <form action="/foodscores/products" id="form_search_header" method="get" name="form_search_header" onsubmit="return check_search_form(this);">
# <input class="fleft" id="input_text_search" name="search" onblur="if (this.value == '') {this.value = 'Search more than 80,000 foods';}" onfocus="if (this.value == 'Search more than 80,000 foods') {this.value = '';}" onkeypress="blank()" type="text" value="agnolotti"/>
# <input class="fleft" id="input_submit_submit" name="" type="submit" value="Search"/>
# <div class="clear"></div>
# </form>
# </div>
# <div class="clear"></div>
# </div>
# </div>
# </div>
# <div class="show_on_mobile movemetotheright" id="mobile_menu_wrapper">
# <a class="nounderlineahref fancy_tooltip" href="/foodscores/" title="Return to the home page"><img alt="TITLE" class="yes_noborder fleft mobile_logo_image hide_show_on_mobile_menu" rel="Home" src="/foodscores/assets/food_database_stylesheet/ewg_logo_mobile_small2-227e2f407422367da97f6a2b564f9a57c3cd7088cccb2746e5a17dc768b23463.png" title="TITLE"/></a>
# <a class="popup-with-form fright" href="#popup3"><div class="hide_show_on_mobile_menu fancy_tooltip" id="mobile_share" title="Share this page">share</div></a>
# <a class="popup-with-form fright" href="#popup2"><div class="hide_show_on_mobile_menu fancy_tooltip" id="mobile_search" title="Search for foods">search</div></a>
# <a class="popup-with-form fright" href="#popup1"><div class="hide_show_on_mobile_menu fancy_tooltip" id="mobile_menu" title="Browse food categories">food categories menu</div></a>
# <div class="fright fancy_tooltip" id="hamburger" title="Site menu">site menu</div>
# <div class="clear"></div>
# </div>
# <div class="movemetotheright swipeme" id="wrapper">
# <div id="dropdown_menu">
# <ul class="clearfix" id="home_ul">
# <li><a class="nounderlineahref" href="/foodscores/products?category_group=Baby+Food">Baby Food</a></li>
# <li><a class="nounderlineahref" href="javascript:submenu_show_by_id('bakedgoods_ul')">Baked Goods</a><ul class="dropdown_submenu" id="bakedgoods_ul" style="display:none;"><li><a class="nounderlineahref" href="/foodscores/products?category_group=Bakery">Bakery</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Breads%2C+Bagels+%26+Rolls">Breads, Bagels &amp; Rolls</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Cakes+%26+Pastries">Cakes &amp; Pastries</a></li></ul></li>
# <li><a class="nounderlineahref" href="javascript:submenu_show_by_id('bakingsupplies_ul')">Baking Supplies</a><ul class="dropdown_submenu" id="bakingsupplies_ul" style="display:none;"><li><a class="nounderlineahref" href="/foodscores/products?category_group=Baking+%26+Dessert+Mixes">Baking &amp; Dessert Mixes</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Baking+Decorations">Baking Decorations</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Baking+Ingredients">Baking Ingredients</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Gelatins%2C+Puddings+%26+Pectins">Gelatins, Puddings &amp; Pectins</a></li></ul></li>
# <div class="clear"></div>
# <li><a class="nounderlineahref" href="javascript:submenu_show_by_id('beverages_ul')">Beverages</a><ul class="dropdown_submenu" id="beverages_ul" style="display:none;"><li><a class="nounderlineahref" href="/foodscores/products?category_group=Coffee">Coffee</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Frozen+Juices">Frozen Juices</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Fruit+%26+Vegetable+Juices+%26+Drinks">Fruit &amp; Vegetable Juices &amp; Drinks</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Iced+Teas">Iced Teas</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Powdered+Drinks">Powdered Drinks</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Sodas">Sodas</a></li></ul></li>
# <li><a class="nounderlineahref" href="/foodscores/products?category_group=Candy">Candy</a></li>
# <li><a class="nounderlineahref" href="javascript:submenu_show_by_id('cannedgoodssoups_ul')">Canned Goods &amp; Soups</a><ul class="dropdown_submenu" id="cannedgoodssoups_ul" style="display:none;"><li><a class="nounderlineahref" href="/foodscores/products?category_group=Canned+%26+Prepared+Beans">Canned &amp; Prepared Beans</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Canned+%26+Prepared+Fruit">Canned &amp; Prepared Fruit</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Canned+%26+Prepared+Tomatoes">Canned &amp; Prepared Tomatoes</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Canned+%26+Prepared+Vegetables">Canned &amp; Prepared Vegetables</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Canned+Meals+%26+Chili">Canned Meals &amp; Chili</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Canned+Meat">Canned Meat</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Canned+Seafood">Canned Seafood</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Soups+%26+Soup+Mixes">Soups &amp; Soup Mixes</a></li></ul></li>
# <div class="clear"></div>
# <li><a class="nounderlineahref" href="javascript:submenu_show_by_id('cerealsbreakfastfoods_ul')">Cereals &amp; Breakfast Foods</a><ul class="dropdown_submenu" id="cerealsbreakfastfoods_ul" style="display:none;"><li><a class="nounderlineahref" href="/foodscores/products?category_group=Breakfast+Foods">Breakfast Foods</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Cold+Cereals+%26+Granola">Cold Cereals &amp; Granola</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Oatmeal+%26+Hot+Cereals">Oatmeal &amp; Hot Cereals</a></li></ul></li>
# <li><a class="nounderlineahref" href="javascript:submenu_show_by_id('chipscookiescrackerssnacks_ul')">Chips, Cookies, Crackers &amp; Snacks</a><ul class="dropdown_submenu" id="chipscookiescrackerssnacks_ul" style="display:none;"><li><a class="nounderlineahref" href="/foodscores/products?category_group=Chips+%26+Snacks">Chips &amp; Snacks</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Cookies+%26+Biscuits">Cookies &amp; Biscuits</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Crackers">Crackers</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Raisins+%26+Other+Fruit+Snacks">Raisins &amp; Other Fruit Snacks</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Soy+Snacks">Soy Snacks</a></li></ul></li>
# <li><a class="nounderlineahref" href="javascript:submenu_show_by_id('condimentsdips_ul')">Condiments &amp; Dips</a><ul class="dropdown_submenu" id="condimentsdips_ul" style="display:none;"><li><a class="nounderlineahref" href="/foodscores/products?category_group=Condiments">Condiments</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Salsa+%26+Dips">Salsa &amp; Dips</a></li></ul></li>
# <div class="clear"></div>
# <li><a class="nounderlineahref" href="javascript:submenu_show_by_id('dairydairyalternatives_ul')">Dairy &amp; Dairy Alternatives</a><ul class="dropdown_submenu" id="dairydairyalternatives_ul" style="display:none;"><li><a class="nounderlineahref" href="/foodscores/products?category_group=Cheese+%26+Cheese+Alternatives">Cheese &amp; Cheese Alternatives</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Half+and+Half+%26+Creamers">Half and Half &amp; Creamers</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Ice+Cream+%26+Frozen+Yogurt">Ice Cream &amp; Frozen Yogurt</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Milk">Milk</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Sour+Cream">Sour Cream</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Yogurt+%26+Yogurt+Drinks">Yogurt &amp; Yogurt Drinks</a></li></ul></li>
# <li><a class="nounderlineahref" href="javascript:submenu_show_by_id('desserts_ul')">Desserts</a><ul class="dropdown_submenu" id="desserts_ul" style="display:none;"><li><a class="nounderlineahref" href="/foodscores/products?category_group=Cakes+%26+Pastries">Cakes &amp; Pastries</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Cookies+%26+Biscuits">Cookies &amp; Biscuits</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Dessert+Toppings">Dessert Toppings</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Ice+Cream+%26+Frozen+Yogurt">Ice Cream &amp; Frozen Yogurt</a></li></ul></li>
# <li><a class="nounderlineahref" href="/foodscores/products?category_group=Egg+%26+Egg+Substitutes">Egg &amp; Egg Substitutes</a></li>
# <div class="clear"></div>
# <li><a class="nounderlineahref" href="javascript:submenu_show_by_id('frozenfoods_ul')">Frozen Foods</a><ul class="dropdown_submenu" id="frozenfoods_ul" style="display:none;"><li><a class="nounderlineahref" href="/foodscores/products?category_group=Frozen+Desserts">Frozen Desserts</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Frozen+Fruits+%26+Vegetables">Frozen Fruits &amp; Vegetables</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Frozen+Juices">Frozen Juices</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Frozen+Meals%2C+Side+Dishes+%26+Snacks">Frozen Meals, Side Dishes &amp; Snacks</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Frozen+Pizzas">Frozen Pizzas</a></li></ul></li>
# <li><a class="nounderlineahref" href="javascript:submenu_show_by_id('fruitsvegetablesbeans_ul')">Fruits, Vegetables &amp; Beans</a><ul class="dropdown_submenu" id="fruitsvegetablesbeans_ul" style="display:none;"><li><a class="nounderlineahref" href="/foodscores/products?category_group=Dried+Beans+%26+Vegetables">Dried Beans &amp; Vegetables</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Raisins+%26+Other+Fruit+Snacks">Raisins &amp; Other Fruit Snacks</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Fresh+Fruits+%26+Vegetables">Fresh Fruits &amp; Vegetables</a></li></ul></li>
# <li><a class="nounderlineahref" href="javascript:submenu_show_by_id('meatseafood_ul')">Meat &amp; Seafood</a>
# <ul class="dropdown_submenu" id="meatseafood_ul" style="display:none;">
# <li><a class="nounderlineahref" href="/foodscores/products?category_group=Meat">Meat</a></li>
# <li><a class="nounderlineahref" href="/foodscores/products?category_group=Poultry">Poultry</a></li>
# <li><a class="nounderlineahref" href="/foodscores/products?category_group=Processed+and+Deli+Meats">Processed and Deli Meats</a></li>
# <li><a class="nounderlineahref" href="/foodscores/products?category_group=Seafood">Seafood</a></li>
# </ul></li>
# <div class="clear"></div>
# <li><a class="nounderlineahref" href="javascript:submenu_show_by_id('nutsdriedfruitfruitsnacks_ul')">Nuts, Dried Fruit &amp; Fruit Snacks</a><ul class="dropdown_submenu" id="nutsdriedfruitfruitsnacks_ul" style="display:none;"><li><a class="nounderlineahref" href="/foodscores/products?category_group=Nuts+%26+Seeds">Nuts &amp; Seeds</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Raisins+%26+Other+Fruit+Snacks">Raisins &amp; Other Fruit Snacks</a></li></ul></li>
# <li><a class="nounderlineahref" href="javascript:submenu_show_by_id('peanutbutterjelliesspreads_ul')">Peanut Butter, Jellies &amp; Spreads</a><ul class="dropdown_submenu" id="peanutbutterjelliesspreads_ul" style="display:none;"><li><a class="nounderlineahref" href="/foodscores/products?category_group=Jams+%26+Jellies">Jams &amp; Jellies</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Peanut+Butter+%26+Other+Nut+Butters">Peanut Butter &amp; Other Nut Butters</a></li></ul></li>
# <li><a class="nounderlineahref" href="javascript:submenu_show_by_id('preparedmealssides_ul')">Prepared Meals &amp; Sides</a><ul class="dropdown_submenu" id="preparedmealssides_ul" style="display:none;"><li><a class="nounderlineahref" href="/foodscores/products?category_group=Prepared+Meals">Prepared Meals</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Side+Dishes">Side Dishes</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Stuffings">Stuffings</a></li></ul></li>
# <div class="clear"></div>
# <li><a class="nounderlineahref" href="javascript:submenu_show_by_id('ricepastagrains_ul')">Rice, Pasta &amp; Grains</a><ul class="dropdown_submenu" id="ricepastagrains_ul" style="display:none;"><li><a class="nounderlineahref" href="/foodscores/products?category_group=Grains">Grains</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Pasta+%26+Noodles">Pasta &amp; Noodles</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Rice">Rice</a></li></ul></li>
# <li><a class="nounderlineahref" href="javascript:submenu_show_by_id('saladdressingssaladtoppings_ul')">Salad Dressings &amp; Salad Toppings</a><ul class="dropdown_submenu" id="saladdressingssaladtoppings_ul" style="display:none;"><li><a class="nounderlineahref" href="/foodscores/products?category_group=Salad+Dressings">Salad Dressings</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Salad+Toppings">Salad Toppings</a></li></ul></li>
# <li><a class="nounderlineahref" href="javascript:submenu_show_by_id('saucesbroths_ul')">Sauces &amp; Broths</a><ul class="dropdown_submenu" id="saucesbroths_ul" style="display:none;"><li><a class="nounderlineahref" href="/foodscores/products?category_group=BBQ+%26+Other+Sauces">BBQ &amp; Other Sauces</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Broths+%26+Other+Cooking+Sauces">Broths &amp; Other Cooking Sauces</a></li><li><a class="nounderlineahref" href="/foodscores/products?category_group=Pasta+%26+Pizza+Sauces">Pasta &amp; Pizza Sauces</a></li></ul></li>
# <div class="clear"></div>
# <li><a class="nounderlineahref" href="/foodscores/products?category_group=Tofu+%26+Meat+Alternatives">Tofu &amp; Meat Alternatives</a></li>
# <li class="menu-highlight"><a class="nounderlineahref" href="/foodscores/products?organic=on&amp;page=1">Certified Organic</a></li>
# <li class="menu-highlight"><a class="nounderlineahref" href="/foodscores/products?gmo_free=on&amp;page=1">Certified GMO Free</a></li>
# <div class="clear"></div>
# <div class="clear"></div>
# </ul>
# </div>
# <div class="margintop15"> </div>
# <div id="internal_banner">
# <a class="nounderlineahref" href="https://act.ewg.org/onlineactions/0fgkOtqcjUyKPgiREUE1AA2?sourceid=1009138" title="Learn more">
# <img alt="Learn more" src="/foodscores/assets/food_database_stylesheet/ewgeats_banner-new_cover-badc00779270cb00648c3d94c2d9ef803422c5b2641194efd5209c6b107a0174.jpg" title="Learn more"/>
# </a>
# </div>
# <div class="margintop15"> </div>
# <div class="product_header product_header_updated hide_on_mobile loaction_views_food_search_products">
# <div class="top_left_right_curved breadcrumbs_updated" id="breadcrumbs">
# <a href="https://www.ewg.org/foodscores">Home</a>
# » "<a href="/foodscores/products?search=agnolotti">agnolotti</a>"
# » Products
# </div>
# <div id="results_for_and_showing_numbers">
# <div class="fleft" id="showing">
# <div class="wrap_title_ty">
# Showing
# <span id="span_pagination">1
# to 2
# of 2
# </span>
# Search results for <span id="results_for_name">"agnolotti"</span>
# </div>
# </div>
# <div class="fright" id="search_score_key">
# <img height="40px" src="/foodscores/assets/food_database_stylesheet/scale_grade_no_arrows-54f3263346b01fc54d162e572864b94e1eb072e6cf7f52060d1ccb7896e6a994.jpg"/>
# </div>
# <div class="clear"></div>
# </div>
# </div>
# <div class="left_column left_column_updated fleft hide_on_mobile loaction_views_food_search_left_column">
# <div class="prod_cats_left_updated" id="prod_cats_left">
# <ul class="cat_ul" id="refine_search_cat_ul">
# <li><strong>Refine search</strong></li>
# </ul>
# <div class="fleft" id="search_left">
# <form action="/foodscores/products" id="form_search_header" method="get" name="form_search_left" onsubmit="return check_search_form(this);">
# <input class="fleft input_text_search_left fancy_tooltip" id="input_text_search" name="search" onblur="if (this.value == '') {this.value = 'Search ...';}" onfocus="if (this.value == 'Search ...') {this.value = '';}" onkeypress="blank()" title="Re-search the database" type="text" value="agnolotti">
# <input class="fleft" id="input_submit_submit" name="" type="submit" value="Go">
# <div class="clear"></div>
# </input></input></form>
# </div>
# <div class="clear"></div>
# <ul class="cat_ul" id="limit_certifications_cat_ul">
# <br/><li><strong>Limit search results</strong></li>
# <li><input type="checkbox"/> <a class="fancy_tooltip nounderlineahref" href="/foodscores/products?gmo_free=on&amp;page=1&amp;search=agnolotti" title="Limit search to Certified GMO free">Certified GMO free <span class="less_opaque">(1)</span></a></li>
# <li><input type="checkbox"/> <a class="fancy_tooltip nounderlineahref" href="/foodscores/products?bpa_free=on&amp;page=1&amp;search=agnolotti" title="Limit search to BPA Free">BPA Free <span class="less_opaque">(2)</span></a></li>
# <br/><li><strong>Limit by category</strong></li>
# <form class="form_aisle_left" method="get" name="form_aisle_left">
# <input autocomplete="off" id="search" name="search" type="hidden" value="agnolotti">
# <div id="left_nav_pulldown">
# <select ,="" class="fancy_tooltip" id="category" name="category" onchange="this.form.submit();" title="Limit search to a specific category">
# <option value="">- select -</option>
# <option value="Pasta - Tortellini &amp; Ravioli">Tortellini &amp; Ravioli (1)</option>
# <option value="Frozen Dinners - Pasta Meals">Frozen Pasta Meals (1)</option>
# </select>
# </div>
# </input></form>
# <br/>
# <li><strong>Limit by score range</strong></li>
# <div class="bar_left">
# <div class="bar_left_col_1 fleft">
# <a class="fancy_tooltip nounderlineahref" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=1&amp;page=1&amp;search=agnolotti" title="Limit search to products with a score of 1">1+</a>
# </div>
# <a class="fancy_tooltip" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=1&amp;page=1&amp;search=agnolotti" title="Limit search to products with a score of 1">
# <div class="bar_left_col_2 fleft">
# <div class="col_1 radius5px" style="width:0%; "> </div>
# </div>
# </a>
# <div class="bar_left_col_3 fleft"><span class="less_opaque"><a class="nounderlineahref" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=1&amp;page=1&amp;search=agnolotti">()</a></span></div>
# <div class="clear"></div> <div class="bar_left_col_1 fleft">
# <a class="fancy_tooltip nounderlineahref" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=2&amp;page=1&amp;search=agnolotti" title="Limit search to products with a score of 2">2+</a>
# </div>
# <a class="fancy_tooltip" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=2&amp;page=1&amp;search=agnolotti" title="Limit search to products with a score of 2">
# <div class="bar_left_col_2 fleft">
# <div class="col_2 radius5px" style="width:0%; "> </div>
# </div>
# </a>
# <div class="bar_left_col_3 fleft"><span class="less_opaque"><a class="nounderlineahref" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=2&amp;page=1&amp;search=agnolotti">()</a></span></div>
# <div class="clear"></div> <div class="bar_left_col_1 fleft">
# <a class="fancy_tooltip nounderlineahref" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=3&amp;page=1&amp;search=agnolotti" title="Limit search to products with a score of 3">3+</a>
# </div>
# <a class="fancy_tooltip" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=3&amp;page=1&amp;search=agnolotti" title="Limit search to products with a score of 3">
# <div class="bar_left_col_2 fleft">
# <div class="col_3 radius5px" style="width:0%; "> </div>
# </div>
# </a>
# <div class="bar_left_col_3 fleft"><span class="less_opaque"><a class="nounderlineahref" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=3&amp;page=1&amp;search=agnolotti">()</a></span></div>
# <div class="clear"></div> <div class="bar_left_col_1 fleft">
# <a class="fancy_tooltip nounderlineahref" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=4&amp;page=1&amp;search=agnolotti" title="Limit search to products with a score of 4">4+</a>
# </div>
# <a class="fancy_tooltip" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=4&amp;page=1&amp;search=agnolotti" title="Limit search to products with a score of 4">
# <div class="bar_left_col_2 fleft">
# <div class="col_4 radius5px" style="width:0%; "> </div>
# </div>
# </a>
# <div class="bar_left_col_3 fleft"><span class="less_opaque"><a class="nounderlineahref" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=4&amp;page=1&amp;search=agnolotti">()</a></span></div>
# <div class="clear"></div> <div class="bar_left_col_1 fleft">
# <a class="fancy_tooltip nounderlineahref" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=5&amp;page=1&amp;search=agnolotti" title="Limit search to products with a score of 5">5+</a>
# </div>
# <a class="fancy_tooltip" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=5&amp;page=1&amp;search=agnolotti" title="Limit search to products with a score of 5">
# <div class="bar_left_col_2 fleft">
# <div class="col_5 radius5px" style="width:0%; "> </div>
# </div>
# </a>
# <div class="bar_left_col_3 fleft"><span class="less_opaque"><a class="nounderlineahref" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=5&amp;page=1&amp;search=agnolotti">()</a></span></div>
# <div class="clear"></div> <div class="bar_left_col_1 fleft">
# <a class="fancy_tooltip nounderlineahref" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=6&amp;page=1&amp;search=agnolotti" title="Limit search to products with a score of 6">6+</a>
# </div>
# <a class="fancy_tooltip" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=6&amp;page=1&amp;search=agnolotti" title="Limit search to products with a score of 6">
# <div class="bar_left_col_2 fleft">
# <div class="col_6 radius5px" style="width:0%; "> </div>
# </div>
# </a>
# <div class="bar_left_col_3 fleft"><span class="less_opaque"><a class="nounderlineahref" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=6&amp;page=1&amp;search=agnolotti">()</a></span></div>
# <div class="clear"></div> <div class="bar_left_col_1 fleft">
# <a class="fancy_tooltip nounderlineahref" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=7&amp;page=1&amp;search=agnolotti" title="Limit search to products with a score of 7">7+</a>
# </div>
# <a class="fancy_tooltip" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=7&amp;page=1&amp;search=agnolotti" title="Limit search to products with a score of 7">
# <div class="bar_left_col_2 fleft">
# <div class="col_7 radius5px" style="width:0%; "> </div>
# </div>
# </a>
# <div class="bar_left_col_3 fleft"><span class="less_opaque"><a class="nounderlineahref" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=7&amp;page=1&amp;search=agnolotti">()</a></span></div>
# <div class="clear"></div> <div class="bar_left_col_1 fleft">
# <a class="fancy_tooltip nounderlineahref" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=8&amp;page=1&amp;search=agnolotti" title="Limit search to products with a score of 8">8+</a>
# </div>
# <a class="fancy_tooltip" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=8&amp;page=1&amp;search=agnolotti" title="Limit search to products with a score of 8">
# <div class="bar_left_col_2 fleft">
# <div class="col_8 radius5px" style="width:0%; "> </div>
# </div>
# </a>
# <div class="bar_left_col_3 fleft"><span class="less_opaque"><a class="nounderlineahref" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=8&amp;page=1&amp;search=agnolotti">()</a></span></div>
# <div class="clear"></div> <div class="bar_left_col_1 fleft">
# <a class="fancy_tooltip nounderlineahref" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=9&amp;page=1&amp;search=agnolotti" title="Limit search to products with a score of 9">9+</a>
# </div>
# <a class="fancy_tooltip" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=9&amp;page=1&amp;search=agnolotti" title="Limit search to products with a score of 9">
# <div class="bar_left_col_2 fleft">
# <div class="col_9 radius5px" style="width:0%; "> </div>
# </div>
# </a>
# <div class="bar_left_col_3 fleft"><span class="less_opaque"><a class="nounderlineahref" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=9&amp;page=1&amp;search=agnolotti">()</a></span></div>
# <div class="clear"></div> <div class="bar_left_col_1 fleft">
# <a class="fancy_tooltip nounderlineahref" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=10&amp;page=1&amp;search=agnolotti" title="Limit search to products with a score of 10">10</a>
# </div>
# <a class="fancy_tooltip" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=10&amp;page=1&amp;search=agnolotti" title="Limit search to products with a score of 10">
# <div class="bar_left_col_2 fleft">
# <div class="col_10 radius5px" style="width:0%; "> </div>
# </div>
# </a>
# <div class="bar_left_col_3 fleft"><span class="less_opaque"><a class="nounderlineahref" href="/foodscores/products?action=index&amp;controller=search&amp;overall_score=10&amp;page=1&amp;search=agnolotti">()</a></span></div>
# <div class="clear"></div>
# </div>
# </ul>
# </div>
# <div class="signup_left_updated ea-wrapper" id="signup_left">
# <div class="ngp-form" data-databag="everybody" data-databag-endpoint="https://profile.ngpvan.com" data-fastaction-endpoint="https://fastaction.ngpvan.com" data-fastaction-nologin="true" data-form-url="https://actions.everyaction.com/v1/Forms/cBMwW7gF10e4D97WA7uL3A2" data-inline-errors="true" data-labels="inline">
# </div>
# <div id="email_opt_out"><small>You can opt out at any time.</small></div>
# </div>
# <div class="vert_banner_updated" id="vert_banner">
# <a class="nounderlineahref" href="https://www.ewg.org/foodscores/products?gmo_free=on&amp;organic=on&amp;page=1" title="Learn more">
# <img alt="learn more" class="noborder" src="/foodscores/assets/food_database_stylesheet/EWG_FS-AD_GMOList_C01-ab59df3a29857cd38be780e61730b10777b8a835bf479b5cd4a4e74bbef68e46.jpg"/>
# </a>
# </div>
# </div>
# <div class="right_column right_column_updated fleft loaction_views_food_search_products">
# <a class="popup-with-form nounderlineahref loaction_views_food_search_products" href="#popup_settings_1"><div class="settings clearfix show_on_mobile loaction_views_food_search_products" id="showing_mobile">Title info loading...</div></a>
# <div class="mfp-hide white-popup-block5 zoom-anim-dialog loaction_views_food_search_products" id="popup_settings_1">
# <h1>Page Settings:</h1>
# <div id="breadcrumbs_mobile"> </div> <hr/>
# <ul id="search_index_mobile"> </ul>
# <ul id="limit_certifications_mobile"> </ul>
# <div class="clear"></div>
# </div>
# <div class="ind_result older_product_ind_result" id="product_ind_result">
# <a class="nounderlineahref" href="/foodscores/products/085239332825-GoodGatherCheeseAgnolottiWithAsparagusPastaFilledWithaFiveCheeseBlendAsparagusinaCreamyGarlicHerbSauceCheeseAgnolottiWithAsparagus">
# <div class="ind_result_img fleft" style=""><img alt="Product Image" class="img_delete_bg_noshow" src="/logos/medium/missing.png" title="Product Image"/></div>
# </a>
# <div class="ind_result_text fleft">
# <a href="/foodscores/products/085239332825-GoodGatherCheeseAgnolottiWithAsparagusPastaFilledWithaFiveCheeseBlendAsparagusinaCreamyGarlicHerbSauceCheeseAgnolottiWithAsparagus">Good &amp; Gather Cheese Agnolotti With Asparagus P... [22 oz]</a>
# <div class="product_category_below_link">
# <a href="/foodscores/products?category=Frozen+Dinners+-+Pasta+Meals">Frozen Pasta Meals</a>
# </div>
# </div>
# <div class="ind_result_score fleft">
# <a href="/foodscores/products/085239332825-GoodGatherCheeseAgnolottiWithAsparagusPastaFilledWithaFiveCheeseBlendAsparagusinaCreamyGarlicHerbSauceCheeseAgnolottiWithAsparagus"><img alt="Score" class="noborder" src="/foodscores/assets/food_database_stylesheet/score_4_5-cbd91fbb4629944b2ef315fee9efaf88be2355cc3b8693a2cb431ce2ad998f8b.jpg" title="Score"/></a>
# </div>
# <div class="ind_result_seals">
# </div>
# <div class="clear"></div>
# </div>
# <div class="ind_result older_product_ind_result" id="product_ind_result">
# <a class="nounderlineahref" href="/foodscores/products/024842751470-BuitoniMushroomAgnolotti">
# <div class="ind_result_img fleft" style=""><img alt="Product Image" class="img_delete_bg_noshow" src="https://phorcys-static.ewg.org/kwikee/024/842/751/470.jpg" title="Product Image"/></div>
# </a>
# <div class="ind_result_text fleft">
# <a href="/foodscores/products/024842751470-BuitoniMushroomAgnolotti">Buitoni Mushroom Agnolotti [9 oz]</a>
# <div class="product_category_below_link">
# <a href="/foodscores/products?category=Pasta+-+Tortellini+%26+Ravioli">Tortellini &amp; Ravioli</a>
# </div>
# </div>
# <div class="ind_result_score fleft">
# <a href="/foodscores/products/024842751470-BuitoniMushroomAgnolotti"><img alt="Score" class="noborder" src="/foodscores/assets/food_database_stylesheet/score_5_0-0da0b624b024ce67c2a6118752e87df6c4c13610a580ddf93a0a7522d8c628b3.jpg" title="Score"/></a>
# </div>
# <div class="ind_result_seals">
# </div>
# <div class="clear"></div>
# </div>
# <div class="clear"></div>
# <div class="clear"></div>
# <div class="disclaimers_below_search_results hide_on_mobile" id="legal_search_prod_images">Please note that EWG obtains the displayed images of products from third parties and that the product's manufacturer or packager may change the product's packaging at any point in time. Therefore, EWG assumes no responsibility for the accuracy of images presented.</div>
# <div class="disclaimers_below_search_results noshow" id="older_gage"><sup style="top:3px;">*</sup>Older Product: Products remain in the database for two years after their label information is recorded in stores. A product with label information last recorded more than a year ago is marked with an * identifying it as an older product.</div>
# <div class="disclaimers_below_search_results noshow" id="discontinued_gage"><sup style="top:3px;">*</sup>Discontinued Product: Products remain in the Database for two years after their label information is recorded in stores, even when they have been discontinued (products may remain in stores and pantries long past the date they cease to be manufactured). EWG marks a product it is aware has been discontinued with a banner identifying it as such.</div>
# </div>
# <div class="clear"></div>
# <div class="margintop30"> </div>
# <script type="text/javascript">
#
# 	$.ajax({
# 	  type: 'GET', url: 'https://api.ewg.org/food_data_tracking/?uuid=website&count_type=1&count=2&', contentType: 'text/plain',
# 	  xhrFields: { withCredentials: false }, headers: {},
# 	  success: function( result ) { console.log("TRACKING done"); },
# 	  error: function() { console.log("TRACKING error"); }
# 	});
#
#
# </script>
# <div id="ewg_guides">
# <div class="fleft" id="eat_well_guide">
# <div class="pistachio_green" id="eat_well_guide_header">
# <a class="nounderlineahref" href="http://www.eatwellguide.org/i.php?pd=Home" title="Read more">
# <img align="left" alt="" src="/foodscores/assets/food_database_stylesheet/EatWellLogo-bb2055a5e11b20b37208835cf3d84b4f409ca732d60780e56c086cd78ff35001.png" style="margin:10px;" width="40%"/>
# </a>
# <h1>eat well guide</h1>
# </div>
# <div id="eat_well_guide_text">
# <h1>find sustainable food!</h1>
# <p>The Eat Well Guide helps consumers find locally grown and sustainably produced food. Listings include farms, restaurants, stores, farmers' markets, and CSAs throughout the United States.</p>
# <a class="nounderlineahref readmore_guide orange" href="http://www.eatwellguide.org/i.php?pd=Home" title="Visit the Eat Well Guide">Visit the Eat Well Guide</a>
# </div>
# </div>
# <div class="fleft" id="other_ewg_guides">
# <div id="other_ewg_guides_header">
# <h1>Other EWG Guides</h1>
# </div>
# <div id="other_ewg_guides_cards">
# <div class="ewg_card fleft">
# <a class="noborder" href="https://www.ewg.org/goodfood/" title="EWG's Good Food on a Tight Budget">
# <img alt="Read more" class="noborder" src="/foodscores/assets/food_database_stylesheet/img_12-1ec4088457c5936b7d307e3defcc8046805df71e17827a330ba93283577b12e8.jpg" title="Read more"/>
# EWG's Good Food on a Tight Budget
# </a>
# </div>
# <div class="ewg_card fleft">
# <a class="noborder" href="https://www.ewg.org/foodnews/" title="EWG's Shopper's Guide to Pesticides in Produce">
# <img alt="Read more" class="noborder" src="/foodscores/assets/food_database_stylesheet/img_13-09fc41eadf5868107d5e2edc059e8b12fd8de5c611e0f53c69cdf6ba9d69c5e4.jpg" title="Read more"/>
# EWG's Shopper's Guide to Pesticides in Produce
# </a>
# </div>
# <div class="ewg_card fleft">
# <a class="noborder" href="https://www.ewg.org/research/ewgs-good-seafood-guide" title="EWG's Good Seafood Guide">
# <img alt="Read more" class="noborder" src="/foodscores/assets/food_database_stylesheet/img_seafood-d347e566e8028f26f8fd0938a1c3bf324f8affdbc58306295adf6cbb89767bb7.jpg" title="Read more"/>
# EWG's Good Seafood Guide
# </a>
# </div>
# <div class="ewg_card fleft">
# <a class="noborder" href="https://www.ewg.org/healthyhomeguide/" title="EWG's Healthy Living: Home Guide">
# <img alt="Read more" class="noborder" src="/foodscores/assets/HLHGFoodScores-ff942b093f1d8ab321ee51815b25f4abd11c47b4d0a488f7aa78bb541080628e.png" title="Read more"/>
# EWG's Healthy Living: Home Guide
# </a>
# </div>
# <div class="ewg_card fleft">
# <a class="noborder" href="https://www.ewg.org/tapwater/" title="EWG's Dirty Dozen Guide to Food Additives">
# <img alt="Read more" class="noborder" src="/foodscores/assets/EWG_OtherResource_TWDB-f179566c139246b3e61648952ff5d95452e7bce0ad15164e8a081b53878d5e1e.jpg" title="Read more"/>
# EWG's Tap Water Database
# </a>
# </div>
# <div class="ewg_card fleft">
# <a class="noborder" href="https://www.ewg.org/research/dirty-dozen-list-endocrine-disruptors" title="EWG and Keep A Breast Foundation's Dirty  Dozen List of Endocrine Disruptors">
# <img alt="Read more" class="noborder" src="/foodscores/assets/food_database_stylesheet/img_health-c30f9b5ee15c78cfbe7b1e620ed3d59df0e87b5c26e465d5f2d8dea36cc02254.jpg" title="Read more"/>
# EWG and Keep A Breast Foundation's Dirty Dozen List of Endocrine Disruptors
# </a>
# </div>
# <div class="clear"></div>
# </div>
# </div>
# <div class="clear"></div>
# </div>
# </div>
# <div id="footer">
# <div class="clearfix" id="footer_inside">
# <h2 class="fleft" id="about_ratings_title">About EWG's Food Scores</h2>
# <div class="fleft" id="about_ratings_txt">
# EWG uses three factors to score foods: Nutrition, Ingredient Concerns, and the Degree of Processing. For more information, please see our
# <a class="nounderlineahref" href="/foodscores/content/methodology" title="Learn more">Methodology &amp; References</a>
# |
# <a class="nounderlineahref" href="https://www.ewg.org/disclaimer" title="Learn more">Legal Disclaimer</a>
# |
# <a class="nounderlineahref" href="https://www.ewg.org/about/privacy" title="Learn more">Privacy Policy</a>
# |
# <a class="nounderlineahref" href="/foodscores/content/faq" title="Learn more">FAQ</a>
# |
# <a class="nounderlineahref" href="/foodscores/content/user-guide" title="Learn more">User's Guide</a>
# |
# <a class="popup-with-form nounderlineahref" href="#contact_front">Contact Us</a>
# <p id="copyright">
# Environmental Working Group is a 501(c)(3) nonprofit corporation, EIN 52-2148600.<br/>
# Data provided by <a class="nounderlineahref" href="http://labelinsight.com/" target="_blank" title="LabelINSIGHT">LabelINSIGHT®</a>. Content Copyright © 2024, <a class="nounderlineahref" href="https://www.ewg.org" target="_blank" title="EWG">EWG</a>. All Rights Reserved.
# </p>
# </div>
# <div class="clear"></div>
# </div>
# </div>
# <div class="mfp-hide white-popup-block-info" id="infopopup">
# <div class="info_h1_header"><h1 id="infotab_h1">Information</h1></div>
# <ul id="info_ul">
# <li><a class="nounderlineahref" href="#" title="Learn more"></a></li>
# <div class="clear"></div>
# </ul>
# <div class="clear"></div>
# </div>
# <div class="mfp-hide white-popup-block3 zoom-anim-dialog" id="popup1">
# <h1>Food Categories:</h1>
# <ul id="mobile_menu_ul">
# <li>1</li>
# <li>2</li>
# <li>3</li>
# <li>4</li>
# </ul>
# <div class="clear"></div>
# </div>
# <div class="mfp-hide white-popup-block4 zoom-anim-dialog" id="popup2">
# <h1 class="noshow">Search:</h1>
# <form action="/foodscores/products" id="mobile_search_form" method="get" name="mobile_search_form" onsubmit="return check_search_form(this);">
# <input class="fleft" id="mobile_search_form_search_text" name="search" onblur="if (this.value == '') {this.value = 'search...';}" onfocus="if (this.value == 'search...') {this.value = '';}" onkeypress="blank()" type="text" value="search..."/>
# <input class="fright" id="mobile_search_form_submit" name="" type="submit" value="GO!"/>
# <div class="clear"></div>
# </form>
# <div class="clear"></div>
# </div>
# <div class="mfp-hide white-popup-block4 zoom-anim-dialog" id="popup3">
# <h1 class="noshow">Share:</h1>
# <div class="clear"></div>
# </div>
# <div class="mfp-hide white-popup-block4 zoom-anim-dialog" id="popup4">
# <h1>Want more food tips?</h1>
# <p>Sign up to receive email updates, action alerts, healthy eating tips, promotions to support our work and more from EWG! You can opt out at any time.</p>
# <form action="#" id="mobile_email_signup_form" method="get" name="mobile_email_signup_form" onsubmit="return check_search_form(this);">
# <input class="fleft" id="mobile_email_signup_form_search_text" name="mobile_email_signup_form_search_text" onblur="if (this.value == '') {this.value = 'Your Email';}" onfocus="if (this.value == 'Your Email') {this.value = '';}" onkeypress="blank()" type="email" value="Your Email"/>
# <input class="fleft" id="mobile_email_signup_form_search_text_2" name="mobile_email_signup_form_search_text_2" onblur="if (this.value == '') {this.value = 'Zip Code';}" onfocus="if (this.value == 'Zip Code') {this.value = '';}" onkeypress="blank()" type="text" value="Zip Code"/>
# <input class="fright" id="mobile_email_signup_form_submit" name="submit" type="submit" value="GO!"/>
# <div class="clear"></div>
# </form>
# <div class="clear"></div>
# </div>
# <div class="mfp-hide white-popup-block4 zoom-anim-dialog" id="contact_front">
# <h1 class="noshow">Select one:</h1>
# <a class="popup-with-form nounderlineahref" href="#contact_back_consumer">
# <img alt="I am a consumer" class="social_share_image" src="/foodscores/assets/food_database_stylesheet/consumer-de218e6d71aaea430279f871fa527fbfaac9ff4700bebf95350c96702a46c949.png" title="I am a consumer"/>
# </a>
# <a class="popup-with-form nounderlineahref" href="#contact_back_company">
# <img alt="I represent a company" class="social_share_image" src="/foodscores/assets/food_database_stylesheet/company-fd9240b986b9d72e789a2f8ebe1d4efb4a56178aec15bc1b1005e14dad583ae0.png" title="I represent a company"/>
# </a>
# <div class="clear"></div>
# </div>
# <div class="mfp-hide white-popup-block7 zoom-anim-dialog" id="contact_back_consumer">
# <h1 class="">Consumer Contact Form:</h1>
# <div class="clear"></div>
# <form class="contact contactform-data" id="consumer_contact_form" method="POST" name="consumer_contact_form">
# <fieldset class="contact-inner">
# <input name="Product URL" type="hidden" value="https://www.ewg.org/foodscores/products">
# <input name="Product ID" type="hidden" value="">
# <input name="xnQsjsdp" type="hidden" value="EmRh54HZC-hthYo*kRl79w$$"/>
# <input name="xmIwtLD" type="hidden" value="GVlTbr9-7x3ARLn4XNiHQXHp987L9qYB"/>
# <input name="actionType" type="hidden" value="Q2FzZXM="/>
# <input name="Department" type="hidden" value="1d150cdc1e5a1cd35710439f27d48b29f3148ec5bcd90913"/>
# <input name="returnURL" type="hidden" value="https://www.ewg.org/foodscores/products">
# <input name="Status" type="hidden" value="Open">
# <input name="Consumer or Manufacturer" type="hidden" value="Consumer">
# <input name="Classification" type="hidden" value="-None-">
# <p class="contact-input">
# <input autofocus="" name="First Name" placeholder="First Name…" required="" type="text"/>
# </p>
# <p class="contact-input">
# <input name="Contact Name" placeholder="Last Name…" required="" type="text"/>
# </p>
# <p class="contact-input">
# <input name="Email" placeholder="Your Email..." required="" type="email"/>
# </p>
# <p class="contact-input">
# <input name="Subject" placeholder="Subject..." required="" type="text"/>
# <input name="MemberCode" placeholder="Member Code" style="display:none;" type="text"/>
# </p>
# <p class="contact-input">
# <textarea name="Description" placeholder="Your Message…" required=""></textarea>
# </p>
# <p class="contact-input">
# EWG reserves the right to make public any information provided to it by companies. I understand that EWG does not accept any confidential or trade secret information that EWG does not have permission to share publicly. If I am contacting EWG on behalf of a company, by clicking "submit," I affirm that I have the authority to contact EWG on my company's behalf and to provide EWG permission to publicly disseminate all information provided.
# </p>
# <p class="contact-submit">
# <input name="save" type="submit" value="Send Your Message"/>
# </p>
# </input></input></input></input></input></input></fieldset>
# </form>
# <div class="clear"></div>
# </div>
# <div class="mfp-hide white-popup-block7 zoom-anim-dialog" id="contact_back_company">
# <h1 class="">Company Contact Form:</h1>
# <div class="clear"></div>
# <form class="contact contactform-data" id="company_contact_form" method="POST" name="company_contact_form">
# <input name="Product URL" type="hidden" value="https://www.ewg.org/foodscores/products">
# <input name="Product ID" type="hidden" value="">
# <input name="xnQsjsdp" type="hidden" value="EmRh54HZC-hthYo*kRl79w$$"/>
# <input name="xmIwtLD" type="hidden" value="GVlTbr9-7x3ARLn4XNiHQXHp987L9qYB"/>
# <input name="actionType" type="hidden" value="Q2FzZXM="/>
# <input name="Department" type="hidden" value="1d150cdc1e5a1cd35710439f27d48b29f3148ec5bcd90913"/>
# <input name="returnURL" type="hidden" value="https://www.ewg.org/foodscores/products">
# <input name="Status" type="hidden" value="Open">
# <input name="Consumer or Manufacturer" type="hidden" value="Manufacturer">
# <input name="Classification" type="hidden" value="-None-">
# <fieldset class="contact-inner">
# <p class="contact-input">
# <input autofocus="" name="Company" placeholder="Company Name…" required="" type="text"/>
# </p>
# <p class="contact-input">
# <input name="First Name" placeholder="First Name…" required="" type="text"/>
# </p>
# <p class="contact-input">
# <input name="Contact Name" placeholder="Last Name…" required="" type="text"/>
# </p>
# <p class="contact-input">
# <input name="Job Title" placeholder="Job Title…" required="" type="text"/>
# </p>
# <p class="contact-input">
# <input name="Email" placeholder="Your Email..." required="" type="email"/>
# </p>
# <p class="contact-input">
# <input name="Phone" placeholder="Phone Number..." required="" type="tel"/>
# </p>
# <p class="contact-input">
# <input name="Subject" placeholder="Subject..." required="" type="text"/>
# <input name="MemberCode" placeholder="Member Code" style="display:none;" type="text"/>
# </p>
# <p class="contact-input">
# <textarea name="Description" placeholder="Your Message…" required=""></textarea>
# </p>
# <p class="contact-input">
# <strong>I would like to update my product's:</strong></p>
# <p class="contact-input">
# <label><input id="ProductProblem_0" name="Product Error[]" type="checkbox" value="Category"/> Category</label><br/>
# <label><input id="ProductProblem_1" name="Product Error[]" type="checkbox" value="Ingredient List"/> Ingredient List</label><br/>
# <label><input id="ProductProblem_2" name="Product Error[]" type="checkbox" value="Name"/> Name</label><br/>
# <label><input id="ProductProblem_3" name="Product Error[]" type="checkbox" value="Product Image"/> Product Image</label><br/>
# <label><input id="ProductProblem_4" name="Product Error[]" type="checkbox" value="Top Findings"/> Top Findings</label><br/>
# <label><input id="ProductProblem_4" name="Product Error[]" type="checkbox" value="Nutrition Panel"/> Nutrition Panel</label><br/>
# </p>
# <p class="contact-input"><strong>Other inquiries:</strong></p>
# <p class="contact-input">
# <label><input id="OtherProblems_0" name="Other Problems[]" type="checkbox" value="Discontinued"/>This product has been discontinued</label><br/>
# <label><input id="OtherProblems_1" name="Other Problems[]" type="checkbox" value="Reformulated"/>This product has been reformulated</label><br/>
# <label><input id="OtherProblems_2" name="Other Problems[]" type="checkbox" value="Unauthorized Seller"/>Unauthorized seller on Amazon</label><br/>
# <label><input id="OtherProblems_3" name="Other Problems[]" type="checkbox" value="Products to Add"/>I have products I want to add to the database</label><br/>
# <label><input id="OtherProblems_4" name="Other Problems[]" type="checkbox" value="Certification not reflected"/>I have a certification listed on my product packaging, but it isn't reflected in your database.</label><br/>
# <label><input id="OtherProblems_5" name="Other Problems[]" type="checkbox" value="Product is Certified Organic"/>My product is certified as having 70% or more organic ingredients</label><br/>
# <label><input id="OtherProblems_5" name="Other Problems[]" type="checkbox" value="Other"/>Other (please describe problem in the description field above)</label><br/>
# </p>
# <p class="contact-input">
# EWG reserves the right to make public any information provided to it by companies. I understand that EWG does not accept any confidential or trade secret information that EWG does not have permission to share publicly. If I am contacting EWG on behalf of a company, by clicking "submit," I affirm that I have the authority to contact EWG on my company's behalf and to provide EWG permission to publicly disseminate all information provided.
# </p>
# <p class="contact-submit">
# <input name="save" type="submit" value="Send Your Message"/>
# </p>
# </fieldset>
# </input></input></input></input></input></input></form>
# <div class="clear"></div>
# </div>
# <a class="nounderlineahref" href="https://act.ewg.org/onlineactions/0fgkOtqcjUyKPgiREUE1AA2?sourceid=1009138" target="_blank" title="Get EWG EATS">
# <img alt="Get the Guide" class="show_on_mobile noborder movemetotheright" id="mobile_guide_img" rel="Guide" src="/foodscores/assets/food_database_stylesheet/edit_get_guide-cc5d1b91669611ccfe5451949e5bf31035e456893ab3e2580acbf70547159471.png" title="Get the Guide"/>
# </a>
# <script>
#  /*
#     $(document).ready(function() {
#
#     $("#owl-example").owlCarousel();
#
#     });
# */
#
#
#     $(document).ready(function() {
#
#     //Sort random function
#     function random(owlSelector){
#     owlSelector.children().sort(function(){
#     return Math.round(Math.random()) - 0.5;
#     }).each(function(){
#     $(this).appendTo(owlSelector);
#     });
#     }
#
#     $("#owl-demo").owlCarousel({
# 	 items : 4,
# 	 autoPlay : true,
# 	  lazyLoad : false,
# 	  stopOnHover : true,
# beforeInit : function(elem){
#     //Parameter elem pointing to $("#owl-demo")
#     // random(elem);
#     }
#
#     });
#
#     });
#
#
# </script>
# <script type="text/javascript">
# $(function(){
#         $('.truncate_title_specific_product_page').succinct({
#             size: 100
#         });
# });
# </script>
# <div class="sharethis-sticky-share-buttons" data-description="EWG's Food Scores rates more than 80,000 foods in a simple, searchable online format to empower people to shop smarter and eat healthier. Each item in the database is scored based on three factors: nutrition, ingredient concerns and degree of processing. &lt;a href='http://ewg.org/foodscores/'&gt;Check it out and see how your favorite foods score.&lt;/a&gt;" data-title="EWG's Food Scores just took the work out of grocery shopping for me!" data-username="ewg"></div>
# <script async="async" src="https://platform-api.sharethis.com/js/sharethis.js#property=64872d63cc05f10013916b6c&amp;product=sticky-share-buttons" type="text/javascript"></script>
# <script type="text/javascript">
# var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-296149-22']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
# </script>
# <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/974244360/?value=0&amp;label=TPA0CPihtQcQiJTH0AM&amp;guid=ON&amp;script=0" style="border-style:none;" width="1"/>
# <script>(function(){if (!document.body) return;var js = "window['__CF$cv$params']={r:'888ff8f4defc23ab',t:'MTcxNjU4MTg4MS4xMzkwMDA='};_cpo=document.createElement('script');_cpo.nonce='',_cpo.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js',document.getElementsByTagName('head')[0].appendChild(_cpo);";var _0xh = document.createElement('iframe');_0xh.height = 1;_0xh.width = 1;_0xh.style.position = 'absolute';_0xh.style.top = 0;_0xh.style.left = 0;_0xh.style.border = 'none';_0xh.style.visibility = 'hidden';document.body.appendChild(_0xh);function handler() {var _0xi = _0xh.contentDocument || _0xh.contentWindow.document;if (_0xi) {var _0xj = _0xi.createElement('script');_0xj.innerHTML = js;_0xi.getElementsByTagName('head')[0].appendChild(_0xj);}}if (document.readyState !== 'loading') {handler();} else if (window.addEventListener) {document.addEventListener('DOMContentLoaded', handler);} else {var prev = document.onreadystatechange || function () {};document.onreadystatechange = function (e) {prev(e);if (document.readyState !== 'loading') {document.onreadystatechange = prev;handler();}};}})();</script><script crossorigin="anonymous" data-cf-beacon='{"rayId":"888ff8f4defc23ab","version":"2024.4.1","token":"46b4951c6a244ba58ebd60d09508ed3f"}' defer="" integrity="sha512-sDIX0kl85v1Cl5tu4WGLZCpH/dV9OHbA4YlKCuCiMmOQIk4buzoYDZSFj+TvC71mOBLh8CDC/REgE0GX0xcbjA==" src="https://static.cloudflareinsights.com/beacon.min.js/vef91dfe02fce4ee0ad053f6de4f175db1715022073587"></script>
# </body>
# </html>
